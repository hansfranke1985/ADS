# %%
import pandas as pd
import csv

# %% [markdown]
# #### Examples from the slides of the lecture

# %%
# creating a dataframe from pandas series
data = {'State': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
 'Year': [2000, 2001, 2002, 2001, 2002, 2003],
 'Population': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
df = pd.DataFrame(data)
df
# Out:
#     State  Year  Population
# 0    Ohio  2000         1.5
# 1    Ohio  2001         1.7
# 2    Ohio  2002         3.6
# 3  Nevada  2001         2.4
# 4  Nevada  2002         2.9
# 5  Nevada  2003         3.2

# %%
# creating a dataframe from data matrix
data = [['Ohio', 2000, 1.5], ['Ohio', 2001, 1.7], ['Ohio', 2002, 3.6],
        ['Nevada', 2001, 2.4],['Nevada', 2002, 2.9], ['Nevada', 2003, 3.2]]
cols = ['State', 'Year', 'Population']
df = pd.DataFrame(data, columns = cols)
df

# %%
# printing the number of columns and the number of rows in a dataframe
print("number of columns = ", len(df.columns))
print('number of rows = ', len(df))
# Out:
# number of columns =  28
# number of rows =  4000

# %%
# creating a dataframe using data stored in a csv file

df = pd.read_csv(filepath_or_buffer = 'movies.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")
df
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 0                Color      James Cameron                   723.0     178.0
# 1                Color     Gore Verbinski                   302.0     169.0
# 2                Color         Sam Mendes                   602.0     148.0
# 3                Color  Christopher Nolan                   813.0     164.0
# 4                  NaN        Doug Walker                     NaN       NaN
# ...                ...                ...                     ...       ...
# 3995             Color        Brett Piper                    18.0      80.0
# 3996             Color    Morgan Spurlock                   193.0     100.0
# 3997             Color      Brandon Trost                    66.0      82.0
# 3998             Color       Joe Swanberg                    65.0      82.0
# 3999   Black and White       Joseph Green                    95.0      70.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 3995                      7.0                     3.0   Steve Diasparra
# 3996                    293.0                     0.0    Amanda Kearsan
# 3997                     32.0                   128.0       Sean Whalen
# 3998                    217.0                   442.0       Lena Dunham
# 3999                      2.0                     6.0       Jason Evers
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 3995                   118.0          NaN           Action|Sci-Fi|Thriller
# 3996                     0.0   11529368.0         Comedy|Documentary|Drama
# 3997                   968.0      40557.0                           Comedy
# 3998                 10000.0      30084.0                     Comedy|Drama
# 3999                    24.0          NaN                    Horror|Sci-Fi
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 3995  ...                 18.0  English      USA             NaN      75000.0
# 3996  ...                404.0  English      USA              PG      65000.0
# 3997  ...                 22.0  English      USA               R      60000.0
# 3998  ...                 23.0  English      USA               R      70000.0
# 3999  ...                152.0  English      USA        Approved      62000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 3995      2015.0                   15.0        4.5           NaN
# 3996      2004.0                    0.0        7.3          1.78
# 3997      2011.0                  407.0        5.6          2.35
# 3998      2014.0                  969.0        5.6          1.85
# 3999      1962.0                   16.0        4.1          1.66
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 3995                   34
# 3996                    0
# 3997                    0
# 3998                  812
# 3999                 1000
#
# [4000 rows x 28 columns]

# %%
df.info() # index & data types
n = 4
dfh = df.head(n)             # get first n rows
dft = df.tail(n)             # get last n rows
dfs = df.describe()          # summary stats cols
top_left_corner_df = df.iloc[:5, :5]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3985 non-null   object
#  1   director_name              3929 non-null   object
#  2   num_critic_for_reviews     3970 non-null   float64
#  3   duration                   3989 non-null   float64
#  4   director_facebook_likes    3929 non-null   float64
#  5   actor_3_facebook_likes     3988 non-null   float64
#  6   actor_2_name               3994 non-null   object
#  7   actor_1_facebook_likes     3997 non-null   float64
#  8   gross                      3449 non-null   float64
#  9   genres                     4000 non-null   object
#  10  actor_1_name               3997 non-null   object
#  11  movie_title                4000 non-null   object
#  12  num_voted_users            4000 non-null   int64
#  13  cast_total_facebook_likes  4000 non-null   int64
#  14  actor_3_name               3988 non-null   object
#  15  facenumber_in_poster       3993 non-null   float64
#  16  plot_keywords              3905 non-null   object
#  17  movie_imdb_link            4000 non-null   object
#  18  num_user_for_reviews       3984 non-null   float64
#  19  language                   3991 non-null   object
#  20  country                    3997 non-null   object
#  21  content_rating             3824 non-null   object
#  22  budget                     3667 non-null   float64
#  23  title_year                 3925 non-null   float64
#  24  actor_2_facebook_likes     3994 non-null   float64
#  25  imdb_score                 4000 non-null   float64
#  26  aspect_ratio               3797 non-null   float64
#  27  movie_facebook_likes       4000 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 875.1+ KB

# %%
col_set = df.iloc[:, 5:10]
col_set
# Out:
#       actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                      855.0  Joel David Moore                  1000.0
# 1                     1000.0     Orlando Bloom                 40000.0
# 2                      161.0      Rory Kinnear                 11000.0
# 3                    23000.0    Christian Bale                 27000.0
# 4                        NaN        Rob Walker                   131.0
# ...                      ...               ...                     ...
# 3995                     3.0   Steve Diasparra                   118.0
# 3996                     0.0    Amanda Kearsan                     0.0
# 3997                   128.0       Sean Whalen                   968.0
# 3998                   442.0       Lena Dunham                 10000.0
# 3999                     6.0       Jason Evers                    24.0
#
#             gross                           genres
# 0     760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1     309404152.0         Action|Adventure|Fantasy
# 2     200074175.0        Action|Adventure|Thriller
# 3     448130642.0                  Action|Thriller
# 4             NaN                      Documentary
# ...           ...                              ...
# 3995          NaN           Action|Sci-Fi|Thriller
# 3996   11529368.0         Comedy|Documentary|Drama
# 3997      40557.0                           Comedy
# 3998      30084.0                     Comedy|Drama
# 3999          NaN                    Horror|Sci-Fi
#
# [4000 rows x 5 columns]

# %%
# print the name of the column and the number of unique values in that column
for col in  df.columns:
    print(col, ' has (', len(df[col].unique()), ') unique values')
# Out:
# color  has ( 3 ) unique values
# director_name  has ( 1893 ) unique values
# num_critic_for_reviews  has ( 519 ) unique values
# duration  has ( 177 ) unique values
# director_facebook_likes  has ( 410 ) unique values
# actor_3_facebook_likes  has ( 883 ) unique values
# actor_2_name  has ( 2430 ) unique values
# actor_1_facebook_likes  has ( 781 ) unique values
# gross  has ( 3377 ) unique values
# genres  has ( 817 ) unique values
# actor_1_name  has ( 1656 ) unique values
# movie_title  has ( 3926 ) unique values
# num_voted_users  has ( 3890 ) unique values
# cast_total_facebook_likes  has ( 3393 ) unique values
# actor_3_name  has ( 2847 ) unique values
# facenumber_in_poster  has ( 19 ) unique values
# plot_keywords  has ( 3831 ) unique values
# movie_imdb_link  has ( 3927 ) unique values
# num_user_for_reviews  has ( 922 ) unique values
# language  has ( 41 ) unique values
# country  has ( 56 ) unique values
# content_rating  has ( 19 ) unique values
# budget  has ( 361 ) unique values
# title_year  has ( 82 ) unique values
# actor_2_facebook_likes  has ( 868 ) unique values
# imdb_score  has ( 76 ) unique values
# aspect_ratio  has ( 19 ) unique values
# movie_facebook_likes  has ( 750 ) unique values

# %%
dataTypeSeries = df.dtypes
for col_idx in range(len(df.columns)):
    print(df.columns[col_idx], 'has type (', dataTypeSeries[col_idx], ')')
# Out:
# color has type ( object )
# director_name has type ( object )
# num_critic_for_reviews has type ( float64 )
# duration has type ( float64 )
# director_facebook_likes has type ( float64 )
# actor_3_facebook_likes has type ( float64 )
# actor_2_name has type ( object )
# actor_1_facebook_likes has type ( float64 )
# gross has type ( float64 )
# genres has type ( object )
# actor_1_name has type ( object )
# movie_title has type ( object )
# num_voted_users has type ( int64 )
# cast_total_facebook_likes has type ( int64 )
# actor_3_name has type ( object )
# facenumber_in_poster has type ( float64 )
# plot_keywords has type ( object )
# movie_imdb_link has type ( object )
# num_user_for_reviews has type ( float64 )
# language has type ( object )
# country has type ( object )
# content_rating has type ( object )
# budget has type ( float64 )
# title_year has type ( float64 )
# actor_2_facebook_likes has type ( float64 )
# imdb_score has type ( float64 )
# aspect_ratio has type ( float64 )
# movie_facebook_likes has type ( int64 )

# %%
# profiling the table (printing the min, max and average of the attributes witth numerical values)
dataTypeSeries = df.dtypes
for col_idx in range(len(df.columns)):
       if (not (dataTypeSeries[col_idx] == 'object')):
            print(df.columns[col_idx], 'has Min = ', df[df.columns[col_idx]].min(), 
                  'Max = ', df[df.columns[col_idx]].max(), 
                  'Average = ', df[df.columns[col_idx]].mean())
# Out:
# num_critic_for_reviews has Min =  1.0 Max =  813.0 Average =  149.6241813602015
# duration has Min =  7.0 Max =  334.0 Average =  108.49586362496866
# director_facebook_likes has Min =  0.0 Max =  23000.0 Average =  751.9707304657674
# actor_3_facebook_likes has Min =  0.0 Max =  23000.0 Average =  718.1226178535607
# actor_1_facebook_likes has Min =  0.0 Max =  640000.0 Average =  7224.773079809857
# gross has Min =  162.0 Max =  760505847.0 Average =  54568682.33053059
# num_voted_users has Min =  5 Max =  1689764 Average =  93085.993
# cast_total_facebook_likes has Min =  0 Max =  656730 Average =  10740.859
# facenumber_in_poster has Min =  0.0 Max =  31.0 Average =  1.4047082394189832
# num_user_for_reviews has Min =  1.0 Max =  5060.0 Average =  298.0381526104418
# budget has Min =  13000.0 Max =  12215500000.0 Average =  44632506.03026997
# title_year has Min =  1920.0 Max =  2016.0 Average =  2003.0068789808918
# actor_2_facebook_likes has Min =  0.0 Max =  137000.0 Average =  1874.2623935903855
# imdb_score has Min =  1.6 Max =  9.5 Average =  6.4338999999999995
# aspect_ratio has Min =  1.18 Max =  16.0 Average =  2.1903845140900717
# movie_facebook_likes has Min =  0 Max =  349000 Average =  8225.47725

# %%
df["director_name"]

# %%
df.loc[(df['content_rating'] == 'PG-13').values, ['actor_1_facebook_likes', 'actor_3_facebook_likes', 'budget']]

# %%
df.iloc[(df['content_rating'] == 'PG-13').values, [5,7,9]]

# %%
idx = df['content_rating'] == 'PG-13'

# %%
s = df['color'].isnull()
df.count()

# %%
df.iloc[:, [5,7,9]]

# %%
cols_set2 = df[df.columns[[5,7,9]]][:]
cols_set2
# Out:
#       actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      855.0                  1000.0
# 1                     1000.0                 40000.0
# 2                      161.0                 11000.0
# 3                    23000.0                 27000.0
# 4                        NaN                   131.0
# ...                      ...                     ...
# 3995                     3.0                   118.0
# 3996                     0.0                     0.0
# 3997                   128.0                   968.0
# 3998                   442.0                 10000.0
# 3999                     6.0                    24.0
#
#                                genres
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 3995           Action|Sci-Fi|Thriller
# 3996         Comedy|Documentary|Drama
# 3997                           Comedy
# 3998                     Comedy|Drama
# 3999                    Horror|Sci-Fi
#
# [4000 rows x 3 columns]

# %% [markdown]
# #### Connecting to a DBMS and writing a query that returns the names of the tables in the database dvdrental

# %%
import psycopg2
conn = psycopg2.connect(database='dvdrental', user='postgres', 
        password='postgres', host='127.0.0.1', port=5432) 
cursor = conn.cursor()

# %%
sql_str = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE"
sql_str = sql_str + " TABLE_TYPE = \'BASE TABLE\'"
sql_str = sql_str + " AND TABLE_SCHEMA = \'public\' "
cursor.execute(sql_str)
table_names = cursor.fetchall()
table_names

# %% [markdown]
# #### Merge (equivalent to join in the SQL)

# %%
dd1 = pd.DataFrame({ 'id_dd1': ['1', '2', '3', '4', '5'], 'Feature1': ['A', 'C', 'E', 'G', 'I'], 'Feature2': ['B', 'D', 'F', 'H', 'J']})
dd2 = pd.DataFrame({ 'id_dd2': ['1', '2', '6', '7', '8'], 'Feature1': ['A', 'C', 'O', 'Q', 'S'], 'Feature2': ['B', 'D', 'P', 'R', 'T']})
union_df = pd.concat([dd1, dd2], axis=1)
union_df

# %%
df_merge_col = pd.merge(dd1, dd2, left_on='id_dd1', right_on = 'id_dd2')
df_merge_col

# %%
df_merge_col = pd.merge(dd1, dd2, left_on='att_dd1', left_on = 'att_dd2'

# %% [markdown]
# ### Exercises

# %%
# read the world.csv into a dataframe df_w
df_w = pd.read_csv(filepath_or_buffer = 'world.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")
df_w
# Out:
#             name      continent     area  population           gdp  \
# 0    Afghanistan           Asia   652230    25500100  2.036400e+10
# 1        Albania         Europe    28748     2821977  1.204400e+10
# 2        Algeria         Africa  2381741    38700000  2.070210e+11
# 3        Andorra         Europe      468       76098  3.222000e+09
# 4         Angola         Africa  1246700    19183590  1.163080e+11
# ..           ...            ...      ...         ...           ...
# 190    Venezuela  South America   916445    28946101  3.824240e+11
# 191      Vietnam           Asia   331212    89708900  1.558200e+11
# 192        Yemen           Asia   527968    25235000  3.283100e+10
# 193       Zambia         Africa   752612    15023315  2.149000e+10
# 194     Zimbabwe         Africa   390757    13061239  9.802000e+09
#
#               capital  tld                                               flag
# 0               Kabul  .af  //upload.wikimedia.org/wikipedia/commons/9/9a/...
# 1              Tirana  .al  //upload.wikimedia.org/wikipedia/commons/3/36/...
# 2             Algiers  .dz  //upload.wikimedia.org/wikipedia/commons/7/77/...
# 3    Andorra la Vella  .ad  //upload.wikimedia.org/wikipedia/commons/1/19/...
# 4              Luanda  .ao  //upload.wikimedia.org/wikipedia/commons/9/9d/...
# ..                ...  ...                                                ...
# 190           Caracas  .ve  //upload.wikimedia.org/wikipedia/commons/0/06/...
# 191             Hanoi  .vn  //upload.wikimedia.org/wikipedia/commons/2/21/...
# 192            Sanaa  .ye  //upload.wikimedia.org/wikipedia/commons/8/89/...
# 193            Lusaka  .zm  //upload.wikimedia.org/wikipedia/commons/0/06/...
# 194            Harare  .zw  //upload.wikimedia.org/wikipedia/commons/6/6a/...
#
# [195 rows x 8 columns]

# %%
# read the bbc.csv into a dataframe df_bbc
df_bbc = pd.read_csv(filepath_or_buffer = 'bbc.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")
df_bbc
# Out:
#             name         region     area  population           gdp
# 0    Afghanistan     South Asia   652225  26000000.0           NaN
# 1        Albania         Europe    28728   3200000.0  6.656000e+09
# 2        Algeria    Middle East  2400000  32900000.0  7.501200e+10
# 3        Andorra         Europe      468     64000.0           NaN
# 4         Angola         Africa  1250000  14500000.0  1.493500e+10
# ..           ...            ...      ...         ...           ...
# 188    Venezuela  South America   881050  26600000.0           NaN
# 189      Vietnam   Asia-Pacific   329247  83600000.0  4.598000e+10
# 190        Yemen    Middle East   536869  21500000.0  1.225500e+10
# 191       Zambia         Africa   752614  11000000.0  4.950000e+09
# 192     Zimbabwe         Africa   390759  12900000.0  6.192000e+09
#
# [193 rows x 5 columns]

# %%
# Find the total popuation of the European countries according to the world table
sum(df_w[df_w['continent'] == 'Europe']['population'])
# Out:
# 610261850

# %%
# Another solution
df_w[df_w['continent'] == 'Europe']['population'].sum()
# Out:
# 610261850

# %%
# read the table game.csv
df_game = pd.read_csv(filepath_or_buffer = 'game.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")
df_game
# Out:
#       id      mdate                              stadium team1 team2
# 0   1001   8-Jun-12             National Stadium, Warsaw   POL   GRE
# 1   1002   8-Jun-12            Stadion Miejski (Wroclaw)   RUS   CZE
# 2   1003  12-Jun-12            Stadion Miejski (Wroclaw)   GRE   CZE
# 3   1004  12-Jun-12             National Stadium, Warsaw   POL   RUS
# 4   1005  16-Jun-12            Stadion Miejski (Wroclaw)   CZE   POL
# 5   1006  16-Jun-12             National Stadium, Warsaw   GRE   RUS
# 6   1007   9-Jun-12                     Metalist Stadium   NED   DEN
# 7   1008   9-Jun-12                           Arena Lviv   GER   POR
# 8   1009  13-Jun-12                           Arena Lviv   DEN   POR
# 9   1010  13-Jun-12                     Metalist Stadium   NED   GER
# 10  1011  17-Jun-12                     Metalist Stadium   POR   NED
# 11  1012  17-Jun-12                           Arena Lviv   DEN   GER
# 12  1013  10-Jun-12                     PGE Arena Gdansk   ESP   ITA
# 13  1014  10-Jun-12             Stadion Miejski (Poznan)   IRL   CRO
# 14  1015  14-Jun-12             Stadion Miejski (Poznan)   ITA   CRO
# 15  1016  14-Jun-12                     PGE Arena Gdansk   ESP   IRL
# 16  1017  18-Jun-12                     PGE Arena Gdansk   CRO   ESP
# 17  1018  18-Jun-12             Stadion Miejski (Poznan)   ITA   IRL
# 18  1019  11-Jun-12                        Donbass Arena   FRA   ENG
# 19  1020  11-Jun-12  Olimpiyskiy National Sports Complex   UKR   SWE
# 20  1021  15-Jun-12                        Donbass Arena   UKR   FRA
# 21  1022  15-Jun-12  Olimpiyskiy National Sports Complex   SWE   ENG
# 22  1023  19-Jun-12                        Donbass Arena   ENG   UKR
# 23  1024  19-Jun-12  Olimpiyskiy National Sports Complex   SWE   FRA
# 24  1025  21-Jun-12             National Stadium, Warsaw   CZE   POR
# 25  1026  22-Jun-12                     PGE Arena Gdansk   GER   GRE
# 26  1027  23-Jun-12                        Donbass Arena   ESP   FRA
# 27  1028  24-Jun-12  Olimpiyskiy National Sports Complex   ENG   ITA
# 28  1029  27-Jun-12                        Donbass Arena   POR   ESP
# 29  1030  28-Jun-12             National Stadium, Warsaw   GER   ITA
# 30  1031   1-Jul-12  Olimpiyskiy National Sports Complex   ESP   ITA

# %%
# Retur the information about the games in which the Dutch team participated 
df_game[(df_game['team1']=="NED" )| (df_game['team2']=="NED" )]
# Out:
#       id      mdate           stadium team1 team2
# 6   1007   9-Jun-12  Metalist Stadium   NED   DEN
# 9   1010  13-Jun-12  Metalist Stadium   NED   GER
# 10  1011  17-Jun-12  Metalist Stadium   POR   NED
