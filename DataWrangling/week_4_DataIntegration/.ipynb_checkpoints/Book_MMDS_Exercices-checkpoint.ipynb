# %% [markdown]
# ![image.png](attachment:18fa0a0f-1ddd-4448-a32a-1493d5576235.png)

# %% [markdown]
# ![image.png](attachment:03d98287-2dbf-47cb-a717-b2195075e06c.png)
# ![image.png](attachment:fde24450-a12e-448e-8da2-a5b0fc368de6.png)
# ![image.png](attachment:4036748e-1aea-4758-a55e-75843494014d.png)

# %% [markdown]
# ![image.png](attachment:f4234ecb-8cb9-419e-8eca-1bd2c370a6a7.png)

# %% [markdown]
# # 3.1.4 Exercises for Section 3.1
#
# - Exercise 3.1.1 : Compute the Jaccard similarities of each pair of the following three sets: {1, 2, 3, 4}, {2, 3, 5, 7}, and {2, 4, 6}.
# - Exercise 3.1.2 : Compute the Jaccard bag similarity of each pair of the following three bags: {1, 1, 1, 2}, {1, 1, 2, 2, 3}, and {1, 2, 3, 4}

# %%
set1 = [1,2,3,4]
set2 = [2,3,5,7]
set3 = [2,4,6]

# Sim(1,2) = 2/6 = 1/3
# Sim(1,3) = 2/5 
# Sim(2,3) = 1/6

bag1 = [1,1,1,2]
bag2 = [1,1,2,2,3]
bag3 = [1,2,3,4]

# Sim(1,2) = 3/9
# Sim(1,3) = 2/8
# Sim(2,3) = 2/8

# %% [markdown]
# # Exercise 3.2.1
#
# ### The most effective way to represent documents as sets, for the purpose of identifying lexically similar documents is to construct from the document the set of short strings that appear within it.
#
# - The set of the first 10 3-shingles is {“The”, “he “, “e m”, “ mo”, “mos”, “ost”, “st “, “t e”, “ ef”, “eff” }.
# - Or {“The most effective”, “most effective way”, “effective way to”, “way to represent”, “to represent documents”, “represent documents as”, “documents as sets”, “as sets for”, “sets for purpose”, “for purpose of”}

# %% [markdown]
# # Exercise 3.3.3 : In Fig. 3.6 is a matrix with six rows.
# - (a) Compute the minhash signature for each column if we use the following three hash functions: h1(x) = 2x + 1 mod 6; h2(x) = 3x + 2 mod 6; h3(x) = 5x + 2 mod 6.
# - (b) Which of these hash functions are true permutations?
#
# - (c) How close are the estimated Jaccard similarities for the six pairs of columns to the true Jaccard similarities?
#
#
# ![image.png](attachment:270575a8-68ae-4836-915f-7b2c3f9a71df.png)

# %% [markdown]
# ![image.png](attachment:d69c7bf8-aaaa-4539-a33a-29eace1723e9.png)

# %% [markdown]
# ![image.png](attachment:d2193dee-eeed-4035-a35e-321f82775e64.png)

# %% [markdown]
# ![image.png](attachment:14efaffd-b69a-42ea-9eec-ce914304e077.png)
